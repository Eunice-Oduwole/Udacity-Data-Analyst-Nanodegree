# %% [markdown]
# # Project: TMDB Movies Data
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
# > In this project, we are going to look into a data set which contains about 10,000 movies gathered from the Movie Database (TMDb), it includes 21 columns such as cast, director, budget, revenue and ratings etc.
#
# > To explore the data set, we aim at providing answers to the following questions;
# ><ul>
# <li>What type of movies are being produced over the years?</li>
# <li>What kind of properties are associated with movies that high revenues?</li>
# <li>Do movies with less runtime recieve higher vote?</li>
# <li>Is a type (genre) of movie associated with runtime? </li>
# </ul>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
from numpy import nan
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
#
# ### General Properties

# %%
df = pd.read_csv('tmdb-movies.csv')

df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
# ...

# %% [markdown]
# In the steps below we shall try to get a general overview of the data set by looking at the shape, information.

# %%
print('Shape')
print(df.shape)
print('\nData Information ')
df.info()
# Out:
# Shape
# (10866, 21)
#
# Data Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
# ...

# %% [markdown]
# > From the above it can be seen that the data contains 10866 entries and 21 columns. Also, it reveals that there are some missing values.
#
# > We shall go further to get a descriptive statistics of the data.

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %% [markdown]
# > From the description of the dataset it can be seen that there are some unrealistic values such as the **budget** and **revenue** having a minimum values of zero (0).

# %% [markdown]
# ### Dropping Extraneous Columns
# Below we shall columns that not relevant to the questions we wish to address in this project.

# %%
df.drop(columns=['overview','homepage','tagline','original_title','release_date','keywords'],inplace= True)
# let's confirm these cloumns have been dropped 
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'cast', 'director',
#        'runtime', 'genres', 'production_companies', 'vote_count',
#        'vote_average', 'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning
# > Here, we shall check the total number of missing vlaues in each cloumn of the dataset.
# ### Drop Rows with Missing Values

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# cast                      76
# director                  44
# runtime                    0
# genres                    23
# production_companies    1030
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum().any()
# Out:
# False

# %%
print(df.shape)
# Out:
# (9771, 15)

# %% [markdown]
# ## Dropping Rows with Duplicated Values

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace= True)
df.duplicated().sum().any()
# Out:
# False

# %% [markdown]
# # Dealing with values outside realistic range
# To address unrealistic values which was detected from the descriptive statistics, we shall replace every row that has a zero value with 'nan'. Then find out the total numbers of such entries.

# %%
# replace zeros with 'nan'

df = df.replace(0, nan)
print(df.isnull().sum())
# Out:
# id                         0
# imdb_id                    0
# popularity                 0
# budget                  4749
# revenue                 5020
# cast                       0
# director                   0
# runtime                   13
# genres                     0
# production_companies       0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj              4749
# revenue_adj             5020
# dtype: int64

# %% [markdown]
# For the runtime we are going to assume that the values are missing at completely as such that, the missing values are distributed similarly to values that are present (MCAR). Thus, we shall fill it with the mean value

# %%
df['runtime'].fillna(df['runtime'].mean(), inplace=True)

# %%
df.dropna(inplace=True)
df.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ## Inspecting and fixing data types
# We are going to convert the runtime, budget and revenue from to float integer

# %%
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                  float64
# revenue                 float64
# cast                     object
# director                 object
# runtime                 float64
# genres                   object
# production_companies     object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
df['runtime'] = df['runtime'].astype(int)

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
# Now that the data has been cleaned and trimmed. We go ahead now now check the shape of the data we now have, compute descriptive statistics and also check the distribution.

# %%
print('Shape:' , df.shape)
df.describe()
# Out:
# Shape: (3805, 15)
#                   id   popularity        budget       revenue      runtime  \
# count    3805.000000  3805.000000  3.805000e+03  3.805000e+03  3805.000000
# mean    40040.372668     1.203784  3.760800e+07  1.089734e+08   109.351117
# std     67585.708616     1.480569  4.232179e+07  1.772976e+08    19.845678
# min         5.000000     0.010335  1.000000e+00  2.000000e+00    15.000000
# 25%      5925.000000     0.470651  1.000000e+07  1.433379e+07    96.000000
# 50%     11253.000000     0.810805  2.500000e+07  4.621664e+07   106.000000
# 75%     38579.000000     1.387163  5.000000e+07  1.260695e+08   119.000000
# max    417859.000000    32.985763  4.250000e+08  2.781506e+09   338.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  3805.000000   3805.000000   3805.000000  3.805000e+03  3.805000e+03
# mean    534.159001      6.170565   2001.229172  4.471977e+07  1.387159e+08
# ...

# %%
df.nunique()
# Out:
# id                      3805
# imdb_id                 3805
# popularity              3803
# budget                   399
# revenue                 3710
# cast                    3784
# director                1683
# runtime                  136
# genres                  1043
# production_companies    3005
# vote_count              1274
# vote_average              53
# release_year              56
# budget_adj              2076
# revenue_adj             3800
# dtype: int64

# %%
df.hist(figsize =(10,10));

# %% [markdown]
# ### What type (genre) of movies are  produced over the years?
# To achieve this, we loop over the years to count the number of each unique genre and appending it to a list and then transpose it in other to add it to the dataframe.

# %%
DF = pd.read_csv('genres.csv')

# %%
#['Comedy', 'Action', 'Adventure', 'Western', 'Science Fiction', 'Drama', 'Family', 'Crime', 'Romance', 'War', 'Thriller','Fantasy', 'History','Mystery', 'Animation', 'Horror', 'Music', 'Documentary', 'TVMovie','Foreign']



numbers=[]
year = 1960
while year < 2016:
    d_year = df['release_year'] == year
    iscomedy = df['genres'].str.contains('Foreign')
    Y = df[iscomedy & d_year]
    G = Y['genres'].count()
    numbers.append(G)
    year = year + 1


J = np.transpose(numbers)
DF['Foreign'] = J
DF.head()
# Out:
#    year  Foreign
# 0  1960        0
# 1  1961        0
# 2  1962        0
# 3  1963        0
# 4  1964        0

# %%
DF.to_csv('genres_year.csv',index=False)

# %%
DF1 = pd.read_csv('genres_years.csv',index_col='year')
DF1.head()
# Out:
#       Comedy  Action  Adventure  Western  Science Fiction  Drama  Family  \
# year
# 1960       2       2          1        1                0      3       0
# 1961       4       2          2        1                0      6       2
# 1962       0       2          3        2                0      5       0
# 1963       1       2          2        0                0      3       0
# 1964       3       1          1        0                0      4       2
#
#       Crime  Romance  War  Thriller  Fantasy  History  Mystery  Animation  \
# year
# 1960      0        2    0         1        0        1        0          0
# 1961      1        1    1         0        0        1        0          1
# 1962      1        0    1         1        0        1        0          0
# 1963      0        2    1         3        0        3        1          0
# 1964      1        2    1         2        1        0        1          0
#
#       Horror  Music  Documentary  TVMovie  Foreign
# year
# ...

# %%
plt.figure(figsize =(25,12))
plt.plot(DF1['Comedy'],color='g',label='Comedy',fillstyle='none');
plt.plot(DF1['Action'],color='orange',label='Action',fillstyle='none');
plt.plot(DF1['Adventure'],color='k',label='Adventure',fillstyle='none');
plt.plot(DF1['Western'],color='r',label='Western',fillstyle='none');
plt.plot(DF1['Science Fiction'],color='m',label='Science Fiction',fillstyle='none');
plt.plot(DF1['Drama'],color='b',label='Drama',fillstyle='none');
plt.plot(DF1['Family'],color='c',label='Family',fillstyle='none');

plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

plt.legend();
plt.rc('legend',fontsize=20)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title('Number of Movies produced over the year',fontsize=20);

# %%
plt.figure(figsize =(25,12))
plt.plot(DF1['Crime'],color='g',label='Crime',fillstyle='none');
plt.plot(DF1['Romance'],color='orange',label='Romance',fillstyle='none');
plt.plot(DF1['War'],color='k',label='War',fillstyle='none');
plt.plot(DF1['Thriller'],color='r',label='Thriller',fillstyle='none');
plt.plot(DF1['Fantasy'],color='m',label='Fantasy',fillstyle='none');
plt.plot(DF1['History'],color='b',label='History',fillstyle='none');
plt.plot(DF1['Mystery'],color='c',label='Mystery',fillstyle='none');

plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

plt.legend();
plt.rc('legend',fontsize=20)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title('Number of Movies produced over the year',fontsize=20);

# %%
plt.figure(figsize =(25,12))
plt.plot(DF1['Animation'],color='g',label='Animation',fillstyle='none');
plt.plot(DF1['Horror'],color='orange',label='Horror',fillstyle='none');
plt.plot(DF1['Music'],color='k',label='Music',fillstyle='none');
plt.plot(DF1['Documentary'],color='r',label='Documentary',fillstyle='none');
plt.plot(DF1['TVMovie'],color='m',label='TVMovie',fillstyle='none');
plt.plot(DF1['Foreign'],color='b',label='Foreign',fillstyle='none');

plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

plt.legend();
plt.rc('legend',fontsize=20)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title('Number of Movies produced over the year',fontsize=20);

# %% [markdown]
# >The figures above shows that starting from the year 2000 the movies been produced are **Drama, Comedy, Thriller and  Action**

# %% [markdown]
# ### Does movies with less runtime recieve higher vote?
# >Here we try to split the runtime into high and low using the median, then we find the average vote for both.

# %%
R_mean =df['runtime'].median()
R_mean
# Out:
# 106.0

# %%
low_runtime =df[df['runtime']< R_mean]
high_runtime =df[df['runtime']>= R_mean]
Samples = df.shape[0]
Samples == low_runtime['vote_average'].count() + high_runtime['vote_average'].count() # should be True
# Out:
# True

# %%
mean_low_vote = low_runtime['vote_average'].mean()
mean_high_vote =high_runtime['vote_average'].mean()
print(mean_low_vote, mean_high_vote)
# Out:
# 5.918581259925889 6.418997912317343

# %%
plt.figure(figsize =(10,8))
locations = [1, 2]
heights = [mean_low_vote, mean_high_vote]
labels = ['Low runtime', 'High runtime']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average vote by Runtime',fontsize=20)
plt.xlabel('Runtime',fontsize=20)
plt.ylabel('Average vote',fontsize=20);

# %% [markdown]
# From the diagram, it is seen that the movies with lower runtime actually recieve lesser vote compared to those with a higer runtime.

# %% [markdown]
# ### What kind of properties are associated with movies that have higher revenues?
# >To get the movies with higher revenues, we selected those whose revenue is greater than the average revenue for the dataset. Then, we obtain a descriptive statistics for it.

# %%
Rev =df['revenue'].mean()
high_revenue =df[df['revenue']>= Rev]
high_revenue.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    1095.000000  1095.000000  1.095000e+03  1.095000e+03  1095.000000
# mean    35945.962557     2.201642  7.449737e+07  2.954684e+08   115.606393
# std     61538.961579     2.221929  5.465937e+07  2.412660e+08    21.166688
# min        11.000000     0.131526  1.130000e+02  1.089795e+08    72.000000
# 25%      1611.000000     1.074489  3.410000e+07  1.504451e+08    99.500000
# 50%      9488.000000     1.618371  6.000000e+07  2.118179e+08   113.000000
# 75%     42890.500000     2.565033  1.000000e+08  3.485801e+08   128.000000
# max    417859.000000    32.985763  3.800000e+08  2.781506e+09   201.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  1095.000000   1095.000000   1095.000000  1.095000e+03  1.095000e+03
# mean   1250.768950      6.392877   2003.270320  8.349348e+07  3.592161e+08
# ...

# %% [markdown]
# >From this table, it shows that on average movies with higher revenues have a budget **7.449737e+07**, runtime of **115.61** and vote_average of **6.39**

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > The result of this project reaveal that as time evole, some type of generes are been produced that others  such as;  **Drama, Comedy, Thriller and  Action**. It was seen that movies with higher runtime recieves a higher vote. And also, discovered that on average movies with higher revenues have a budget **7.449737e+07**, runtime of **115.61** and vote_average of **6.39**
#
# > **Limitations:** The conclusions were made on a smaller dataset due to the fact that a larger percentage of data had no information on budget and revenue. Filling them with the mean could make our results bias and to avoid this, they dropped.
